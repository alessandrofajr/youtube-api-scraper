# %%
import pandas as pd

# %%
#Lendo dois CVVs

df1 = pd.read_csv('alessandro.csv', index_col=0) 
df2 = pd.read_csv('alessandro2.csv', index_col=0)

# %%
df1
# Out:
#                   channel                                     title  \
# 0  Alessandro Feitosa Jr.     Preconceito otimizado - Olhos de Robô
# 1  Alessandro Feitosa Jr.   Vigilância engatilhada - Olhos de Robô
# 2  Alessandro Feitosa Jr.    Neutralidade camuflada - Olhos de Robô
# 3  Alessandro Feitosa Jr.                  Teaser -  Olhos de Robô
# 4  Alessandro Feitosa Jr.  Privacidade desabilitada - Olhos de Robô
#
#       video_id                                  video_description  \
# 0  1WZxJ5g9rl0  Vídeo da série de minidocumentários Olhos de R...
# 1  -rBA4R9QHAk  Vídeo da série de minidocumentários Olhos de R...
# 2  -NY8FYo-hY0  Vídeo da série de minidocumentários Olhos de R...
# 3  MwhySoa5OHU  Teaser da série de minidocumentários Olhos de ...
# 4  e8PeR4eecs8  Vídeo da série de minidocumentários Olhos de R...
#
#          published_date             extraction_date  views  \
# 0  2021-10-02T18:48:57Z  2021-10-02 15:50:52.773412     45
# ...

# %%
df2
# Out:
#                   channel                                     title  \
# 0  Alessandro Feitosa Jr.     Preconceito otimizado - Olhos de Robô
# 1  Alessandro Feitosa Jr.   Vigilância engatilhada - Olhos de Robô
# 2  Alessandro Feitosa Jr.    Neutralidade camuflada - Olhos de Robô
# 3  Alessandro Feitosa Jr.  Privacidade desabilitada - Olhos de Robô
#
#       video_id                                  video_description  \
# 0  1WZxJ5g9rl0  Vídeo da série de minidocumentários Olhos de R...
# 1  -rBA4R9QHAk  Vídeo da série de minidocumentários Olhos de R...
# 2  -NY8FYo-hY0  Vídeo da série de minidocumentários Olhos de R...
# 3  e8PeR4eecs8  Vídeo da série de minidocumentários Olhos de R...
#
#          published_date             extraction_date  views  \
# 0  2021-10-02T18:48:57Z  2021-10-02 15:55:13.603898     45
# 1  2021-10-02T18:49:00Z  2021-10-02 15:55:13.603898     44
# 2  2021-10-02T18:49:03Z  2021-10-02 15:55:13.603898     47
# ...

# %%
#Comparando os dois CSVs e criando um terceiro dataframe somente com as linhas diferentes
df3 = pd.concat([df1,df2]).drop_duplicates(subset = ['video_id'], keep=False)

# %%
df3
# Out:
#                   channel                     title     video_id  \
# 3  Alessandro Feitosa Jr.  Teaser -  Olhos de Robô  MwhySoa5OHU
#
#                                    video_description        published_date  \
# 3  Teaser da série de minidocumentários Olhos de ...  2021-10-02T18:49:07Z
#
#               extraction_date  views  \
# 3  2021-10-02 15:50:52.773412     74
#
#                                           thumbnail
# 3  https://i.ytimg.com/vi/MwhySoa5OHU/hqdefault.jpg

# %%
df_all = df1.merge(df2.drop_duplicates(), on=['video_id'], how='left', indicator=True)
df_drop = df_all.query('_merge == "left_only"')
df_drop
# Out:
#                 channel_x                   title_x     video_id  \
# 3  Alessandro Feitosa Jr.  Teaser -  Olhos de Robô  MwhySoa5OHU
#
#                                  video_description_x      published_date_x  \
# 3  Teaser da série de minidocumentários Olhos de ...  2021-10-02T18:49:07Z
#
#             extraction_date_x  views_x  \
# 3  2021-10-02 15:50:52.773412       74
#
#                                         thumbnail_x channel_y title_y  \
# 3  https://i.ytimg.com/vi/MwhySoa5OHU/hqdefault.jpg       NaN     NaN
#
#   video_description_y published_date_y extraction_date_y  views_y thumbnail_y  \
# 3                 NaN              NaN               NaN      NaN         NaN
#
#       _merge
# 3  left_only
